# %% [markdown]
# <a href="https://colab.research.google.com/github/MartinVIllesca/CC6205-Procesamiento-de-Lenguaje-Natural/blob/master/assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tarea 1 NLP : Competencia de Clasificación de Texto
# -------------------------------

# %% [markdown]
# - **Nombre:** Jou-Hui Ho Ku, Martín Valderrama
#
# - **Usuario o nombre de equipo en Codalab:** PibJou

# %% [markdown]
# ## Objetivo e Instrucciones:
#
# ### Objetivo
#
# Esta tarea consiste en participar en una competencia cuyo objetivo es la clasificación de tweets según su intensidad de emoción. Específicamente:
#
# Tendrán 4 datasets de tweets de distintas emociones: `anger`, `fear`, `sadness` y `joy`. Para cada uno de estos datasets, deberán crear un clasificador que indique la intensidad de dicha emoción en sus tweets (`low`, `medium`, `high`).

# %% [markdown]
# ###  Fecha de Entrega:
#
# Por ser anunciada una vez termine el paro. Se publicará la fecha en ucursos.

# %% [markdown]
# ### Detalles e instrucciones de la competencia:
#
# - La competencia consiste en resolver 4 problemas de clasificación distintos, cada uno de tres clases. Por cada problema deberán crear un clasificador distinto. La evaluación de la competencia se realiza en base a 4 métricas: AUC, Kappa y Accuracy. Los mejores puntajes en cada ítem serán los que ganen.
#
# - Para comenzar se les entregará en este notebook el baseline y la estructura del reporte. El baseline es el código que realiza creación de features y clasificación básica. Los puntajes de este serán ocupados como base para la competencia: deben superar sus resultados para ser bien evaluados.
#
# - Para participar, deben registrarse en Codalab y luego ingresar a la competencia usando el siguiente [link]( https://competitions.codalab.org/competitions/24121?secret_key=f5eb2d95-b36e-4aad-8fc5-4d9d77f4e4dc).
#
# - **Es requisito entregar el reporte con el código y haber participado en la competencia para ser evaluado.**
#
# - Pueden hacer grupos de máximo 2 alumnos. Cada grupo debe tener un nombre de equipo (En codalab, ir a settings y después cambiar Team Name). Solo una persona debe administrar la cuenta del grupo.
#
# - En total pueden hacer un **máximo de 4 envíos/submissions** (tanto para equipos como para envíos indivuales).
#
# - Hagan varios experimentos haciendo cross-validation o evaluación sobre una sub-partición antes de enviar sus predicciones a Codalab. Asegúrense que la distribución de las clases sea balanceada en las particiones de training y testing. Verificar que el formato de la submission coincida con el de la competencia. De lo contrario, se les será evaluado incorrectamente.
#
# - Estar top 5 en alguna métrica equivale a 1 punto extra en la nota final.
#
# - No se limiten a los contenidos vistos ni a scikit ni a este baseline. ¡Usen todo su conocimiento e ingenio en mejorar sus sistemas!
#
# - Todas las dudas escríbanlas en el hilo de U-cursos de la tarea. Los emails que lleguen al equipo docente serán remitidos a ese medio.

# %% [markdown]
# ### Reporte
#
# Este debe cumplir la siguiente estructura:
#
# 1.	**Introducción**: Presentar brevemente el problema a resolver, los métodos y representaciones utilizadas en el desarrollo de la tarea y conclusiones obtenidas. (0.5 Puntos)
# 2.	**Representaciones**: Describir los atributos y representaciones usadas como entrada de los clasificadores. Si bien, con Bag of Words (baseline) ya se comienzan a percibir buenos resultados, pueden mejorar su evaluación agregando más atributos y representaciones diseñadas a mano. Mas abajo encontrarán una lista útil de estos que les podrá ser de utilidad. (1.5 puntos)
# 3.	**Algoritmos**: Describir brevemente los algoritmos de clasificación usados. (0.5 puntos)
# 4.	**Métricas de evaluación**: Describir brevemente las métricas utilizadas en la evaluación indicando que miden y su interpretación. (0.5 puntos)
# 5.	**Experimentos**: Reportar todos sus experimentos. Comparar los resultados obtenidos utilizando diferentes algoritmos y representaciones. Estos experimentos los hacen sobre la sub-partición de evaluación que deben crear (o pueden usar cross-validation). Incluyan todo el código de sus experimentos aquí. ¡Es vital haber realizado varios experimentos para sacar una buena nota! (2 puntos)
# 6.	**Conclusiones**: Discutir resultados, proponer trabajo futuro. (1 punto)

# %% [markdown]
# ### Baseline
#
# Por último, el baseline contiene un código básico que:
#
# - Obtiene los dataset.
# - Divide los datasets en train (entrenamiento y prueba) y target set (el que clasificar para subir a la competencia).
# - Crea un Pipeline que:
#     - Crea features personalizadas.
#     - Transforma los dataset a bag of words (BoW).
#     - Entrena un clasificador usando cada train set.
# - Clasifica y evalua el sistema creado usando el test set.
# - Clasifica el target set.
# - Genera una submission con el target en formato zip en el directorio en donde se está ejecutando el notebook.
#
#
# Algunas pistas sobre como mejorar el rendimiento de los sistemas que creen. (Esto tendrá mas sentido cuando vean el código)
#
# - **Vectorizador**: investigar los modulos de `nltk`, en particular, `TweetTokenizer`, `mark_negation` para reemplazar los tokenizadores. También, el parámetro `ngram_range` (Ojo que el clf naive bayes no debería usarse con n-gramas, ya que rompe el supuesto de independencia). Además, implementar los atributos que crean útiles desde el listado del el enunciado. Investigar también el vectorizador tf-idf.
#
# - **Clasificador**: investigar otros clasificadores mas efectivos que naive bayes. Estos deben poder retornar la probabilidad de pertenecia de las clases (ie: implementar la función `predict_proba`).
#
# - **Features**: Recuerden que pueden implementar todas las features que se les ocurra! Aquí les adjuntamos algunos ejemplos:
#     -	Word n-grams.
#     -	Character n-grams.
#     -	Part-of-speech tags.
#     -	Sentiment Lexicons (Lexicon = A set of words with a label or associated value.).
#         - Count the number of positive and negative words within a sentence.
#         - If the lexicon has associated intensity of feeling (for example in a decimal), then take the average of the intensity of the sentence according to the feeling, the sum, etc.
#         -	A good lexicon of sentiment: [Bing Liu](http://www.cs.uic.edu/~liub/FBS/opinion-lexicon-English.rar)
#         - A reference with a lot of [sentiment lexicons](https://medium.com/@datamonsters/sentiment-analysis-tools-overview-part-1-positive-and-negative-words-databases-ae35431a470c).
#     -	The number of elongated words (words with one character repeated more than two times).
#     -	The number of words with all characters in uppercase.
#     -	The presence and the number of positive or negative emoticons.
#     -	The number of individual negations.
#     -	The number of contiguous sequences of dots, question marks and exclamation marks.
#     -	Word Embeddings: Here are some good ideas on how to use them.
#     https://stats.stackexchange.com/questions/221715/apply-word-embeddings-to-entire-document-to-get-a-feature-vector
#
# - **Reducción de dimensionalidad**: También puede serles de ayuda. Referencias [aquí](https://scikit-learn.org/stable/modules/unsupervised_reduction.html).
#
# - Por último, pueden encontrar mas referencias de cómo mejorar sus features, el vectorizador y el clasificador [aquí](https://affectivetweets.cms.waikato.ac.nz/benchmark/).

# %% [markdown]
# ----------------------------------------
#
# (borrar este bloque despues)
# 1.	**Introducción**: Presentar brevemente el problema a resolver, los métodos y representaciones utilizadas en el desarrollo de la tarea y conclusiones obtenidas. (0.5 Puntos)
# 2.	**Representaciones**: Describir los atributos y representaciones usadas como entrada de los clasificadores. Si bien, con Bag of Words (baseline) ya se comienzan a percibir buenos resultados, pueden mejorar su evaluación agregando más atributos y representaciones diseñadas a mano. Mas abajo encontrarán una lista útil de estos que les podrá ser de utilidad. (1.5 puntos)
# 3.	**Algoritmos**: Describir brevemente los algoritmos de clasificación usados. (0.5 puntos)
# 4.	**Métricas de evaluación**: Describir brevemente las métricas utilizadas en la evaluación indicando que miden y su interpretación. (0.5 puntos)
# 5.	**Experimentos**: Reportar todos sus experimentos. Comparar los resultados obtenidos utilizando diferentes algoritmos y representaciones. Estos experimentos los hacen sobre la sub-partición de evaluación que deben crear (o pueden usar cross-validation). Incluyan todo el código de sus experimentos aquí. ¡Es vital haber realizado varios experimentos para sacar una buena nota! (2 puntos)
# 6.	**Conclusiones**: Discutir resultados, proponer trabajo futuro. (1 punto)

# %% [markdown]
# ## 1. Introducción

# %% [markdown]
# El problema a abordar en este trabajo es el análisis de sentimientos de tweets. Se tiene un dataset de tweets clasificados por sentimiento (joy, fear, sadness, anger), y en cada sentimiento, a su vez, los tweets se clasifican por intensidad (alto, medio o bajo).
#
# Para resolver este problema, se utilizan distintas representaciones de los datos, tales como Bag Of Words, la representación Tf-Idf, Word Embeddings, y también se extraen características relevantes de los textos, como por ejemplo la cantidad de signos de exclamación que contengan.
#
# Una vez convertidos los textos a su representación, se utilizan métodos de NaiveBayes, SVM, regresión logística y MLP para clasificar el nivel de sentimiento en cada clase.
#
# Para realizar tal tarea, se sigue el código entregado por el cuerpo docente a modo de marco de trabajo. En este se realiza la carga de datos, la creación de las transformaciones de los datos y la creación de los clasificadores, todo en utilizando las facultades de la librería sklearn con pipeline y feature union.
#
# Se realizan múltiples experimentos para obtener los modelos que mejor clasifiquen a los tweets y con ello después realizar una predicción sobre el conjunto de testeo que después es subido a la competencia de codalab.
#
# Con esta tarea se pretende abordar la metodología de trabajo para participar en competencias de Data Science donde se deben crear múltiples instancias de extracción de características y creación de clasificadores. Además, se deben aplicar los conocimientos adquiridos en el curso de Procesamiento de Lenguaje Natural para obtener los mejores rendimientos.

# %% [markdown]
# ## 2. Representaciones

# %% [markdown]
# Se implementan distintas representaciones de los textos, mediante las siguientes clases:
#
#
# - **CountVectorizer** \
#     Consiste en una representación de los textos en Bag of Words.
#
# - **TfidfVectorizer**\
#     Calcula la matriz Tf-Idf asociada al dataset. El algoritmo funciona sobre un tokenizer el cual por defecto se realiza separando solamente las palabras del tweet en este caso. Se puede utilizar con distintos Tokenizers, en esta tarea se prueba un caso con el TweetTokenizer de la librería nltk.
#
# - **TweetTokenizer**\
#     Es un tokenizer pre-definido de la librería nltk, el cual reconoce carácteres especiales de los mensajes de Twitter como emojis en símbolos o puntutación, incluso hashtags.
#
#
# - **CharCountTransformer**: \
#     Esta representación considera una serie de conteos "manuales" implementados a continuación. Esta incluye:
#     - **Caracteres relevantes dentro del texto**, tales como:
#         - Cantidad de signos de exclamación
#         - Cantidad de signos de interrogación
#         - Cantidad de letras repetidas más de tres veces
#         - Cantidad de letras en mayúscula
#         - Cantidad de puntos seguidos
#     - Entrega también el largo del tweet
#     - Se utiliza la librería _emoji_ para codificar los emojis de los tweets, y la librería _emosent_ para extraer un sentiment score del emoji, además de la polaridad del sentimiento. Cabe destacar que existen algunos emojis que no están en la librería _emosent_, por lo que fue necesario evaluar su polaridad bajo inspección, y evaluar si el nombre del emoji contiene palabras positivas o negativas.
#     - Además, se marcan previamente las palabras que siguen a una negación, concatenando el string \_NEG luego de la palabra, para que sea considerada diferente a la misma palabra, pero en un contexto positivo.
#
# - **Doc2VecTransformer** \
#     Word embeddings con el modelo _glove_twitter_ ya entrenado. Se considera el máximo de cada tweet, considerando que se quiere realizar un análisis de sentimientos, y otras operaciones como suma o promedio podrían causar una pérdida de información.
#     Posee distintas configuraciones:
#     - Con y sin eliminar stopwords
#     - Con y sin pasar a minúscula
#
# - **LiuFeatureExtractor**\
#     Extrae la cantidad de palabras positivas y palabras negativas, usando el dataset de Bing Liu.
#
# - **VaderFeatureExtractor**\
#     Extrae el puntaje de sentimiento de acuerdo al método de Vader (https://github.com/cjhutto/vaderSentiment). Entrega un puntaje de positividad, negatividad, neutralidad, y de composición.
#
# - **TextBlobTransformer** \
#     Implementa un análisis de sentimientos usando TextBlob (https://textblob.readthedocs.io/en/dev/quickstart.html#sentiment-analysis). Esta clase entrega un puntaje (de -1.0 a 1.0) asociado a cada tweet, que representa el nivel de sentimiento que contiene.

# %% [markdown]
# ## 3. Algoritmos

# %% [markdown]
# Los algoritmos utilizados en este trabajo son:
#
# - **Naive Bayes** es un algoritmo de búsqueda de pertenencia a una clase dada de acuerdo al contenido del documento. Compara las palabras presentes en el documento con las presentes en el vocabulario pertenenciente a la clase, obteniendo la verosimilitud de que dicho documento pertenezca a dicha clase. Compara cada una de las probabilidades para obtener la pertenencia.
#
# - **SVM** es un clasificador basado en vectores de soporte, son los que determinan el margen entre dos clases. La forma de separar las clases es maximizando el margen de la clase con el resto de los datos, esto con la aproximación del hiperplano de separación.
#
# - **Logistic Regression** clasifica según un ajuste de una sigmoide con input lineal ax + b (con resultado 0 o 1) para realizar la separación entre las clases. Utiliza la estrategia uno vs uno, o uno vs todos para determinar la separación.
#
# - **MLP Classifier** es un clasificador basado en redes neuronales totalmente conectadas, puede tener múltiples capas ocultas, mientras más neuronas tenga el clasificador, más parámetros tendrá que entrenar con backpropagation.

# %% [markdown]
# ## 4. Métricas de Evaluación

# %% [markdown]
# - **AUC**: es una métrica que mide la capacidad del modelo de distinguir entre clases variando el threshold de separación, es decir, la probabilidad con la que se considera la pertenencia a una clase. En la imagen inferior obtenida de [towardsdatascience.com](https://towardsdatascience.com/understanding-auc-roc-curve-68b2303cc9c5), se muestra una separación entre las distribuciones de probabilidad de cada clase y la ROC resultante al mover el threshold.
#
# - **Kappa**: El coeficiente Cohen's Kappa es un estadístico de la capacidad del modelo de "estar de acuerdo" con otro anotador o clasificador, en este caso, con el anotador de los labels que consideramos reales. El coeficiente de Kappa se calcula como:
#
# $$K = \frac{0A - AC}{1 - AC}$$
#
# Donde $0A$ es el accuracy obtenido, y $AC$ es la probabilida de haberle acertado por coincidencia. Un coeficiente de Cohen Kappa superior a 0.8 indica un buen rendimiento del modelo sobre haberle acertado por coincidencia. Mientras que un coeficiente inferior o negativo, indica un mal rendimiento del modelo.
#
# - **Accuracy**: El accuracy es el coeficiente de evaluación más usado para evaluar a un modelo. Con él se calcula el nivel de acuerdo que tiene el modelo con los labels considerados reales, se calcula como la suma de la diagonal de la matriz de confusión sobre el total de las muestras consideradas en la evaluación. Mientras más cercano a 1 quire decir que el modelo se parece más a los labels considerados reales, mientras que un accuracy 0, quiere decir que el modelo no pudo predecir correctamente ninguna etiqueta.

# %% [markdown]
# ## 5. Experimentos

# %% [markdown]
# Se realizan variados experimentos para escoger los parámetros adecuados de cada representación, tales como:
#
# - CountVectorizer:
#     - con/sin eliminar stopwords
#     - con/sin convertir a minúscula
# - TfidfVectorizer:
#     - con/sin eliminar stopwords
#     - con/sin convertir a minúscula
# - Doc2VecTransformer:
#     - con/sin eliminar stopwords
#     - con/sin stemming
#     - con/sin lemmatization
#     - con/sin convertir a minúscula
#
# Con esto, se escoge la configuración que arroja el mejor resultado. Los experimentos relevantes presentados son los siguientes, donde en cada uno de ellos se consideró 3-fold cross validation, para obtener una métrica menos sesgada.
#
#
# | Experimento | Representaciones | Feature Selection | Clasificador |
# | --- | --- | --- | --- |
# | 0 | CountVectorizer | - | NB |
# | 1 | CountVectorizer | - | MLP |
# | 2 | CountVectorizer | - | LR |
# | 3 | CountVectorizer + CharsCountTransformer | - | LR |
# | 4 | TfidfVectorizer + CharsCountTransformer | - | LR |
# | 5 | TfidfVectorizer + Word2Vec (eliminando stopwords) | - | LR |
# | 6 | TfidfVectorizer + Word2Vec | - | LR |
# | 7 | CountVectorizer + Word2Vec | - | LR |
# | 8 | TfidfVectorizer + Word2Vec (stemming) | - | LR |
# | 9 | TfidfVectorizer + Word2Vec (lemmatization) | - | LR |
# | 10 | CountVectorizer + CharsCountTransformer + Liu + Vader| - | SVM |
# | 11 | CountVectorizer + CharsCountTransformer + Liu + Vader| - | LR |
# | 12 | CountVectorizer + CharsCountTransformer + Word2Vec + Liu + Vader + TextBlob | - | LR |
# | 13 | CountVectorizer + CharsCountTransformer + Word2Vec + Liu + Vader + TextBlob | LR | SVM |

# %% [markdown]
# ### Importar librerías y utiles

# %%
import pandas as pd
import os
import numpy as np
import shutil

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import confusion_matrix, cohen_kappa_score, classification_report, accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split, cross_validate, cross_val_predict
from sklearn.base import BaseEstimator, TransformerMixin
from nltk.tokenize import TweetTokenizer
from nltk.sentiment.util import mark_negation
from nltk.sentiment import SentimentIntensityAnalyzer
from nltk.corpus import opinion_lexicon, stopwords
from nltk.stem import SnowballStemmer, WordNetLemmatizer

# !pip install -U emojis
# !pip install emosent-py
# !pip install emoji --upgrade
import emoji
import emojis
from emosent import get_emoji_sentiment_rank

import gensim.downloader as api
import string

from collections import Counter

# %%
import nltk
# nltk.download('opinion_lexicon')
# nltk.download('vader_lexicon')
# nltk.download('stopwords')
# nltk.download('punkt')
# nltk.download('wordnet')

# %%
# !pip install -U textblob
# !python -m textblob.download_corpora
from textblob import TextBlob

# %%
negative_words = pd.read_csv('https://raw.githubusercontent.com/MartinVIllesca/CC6205-Procesamiento-de-Lenguaje-Natural/master/data_t1/opinion-lexicon-English/negative-words.csv',
                             sep='\n', header=None, error_bad_lines=False)
positive_words = pd.read_csv('https://raw.githubusercontent.com/MartinVIllesca/CC6205-Procesamiento-de-Lenguaje-Natural/master/data_t1/opinion-lexicon-English/positive-words.csv',
                             sep='\n', header=None, error_bad_lines=False)

positive_words = np.hstack((list(positive_words),
                            'hugging_face',
                            'popcorn'))
negative_words = np.hstack((list(negative_words),
                            'spider',
                            'face_with_head-bandage',
                            'upside-down_face',
                            'face_with_rolling_eyes',
                            'zipper-mouth_face',
                            'slightly_frowning_face'))

# %%
# # limpiar puntuaciones y separar por tokens.
# punctuation = string.punctuation + "«»“”‘’…—"
stopwords = pd.read_csv(
    'https://raw.githubusercontent.com/Alir3z4/stop-words/master/english.txt'
).values
stopwords = Counter(stopwords.flatten().tolist())

# %%
# Doc2Vec Model
glove_twitter = api.load("glove-twitter-25")  # download the model and return as object ready for use
# glove_twitter.most_similar("cat")

stemmer = SnowballStemmer('english')
lemmatizer = WordNetLemmatizer()
# Out:
# 20157 | INFO | loading projection weights from /home/martin/gensim-data/glove-twitter-25/glove-twitter-25.gz
# 20157 | INFO | loaded (1193514, 25) matrix from /home/martin/gensim-data/glove-twitter-25/glove-twitter-25.gz

# %% [markdown]
# ### Definir métodos de evaluación

# %%
def auc_score(test_set, predicted_set):
    high_predicted = np.array([prediction[2] for prediction in predicted_set])
    medium_predicted = np.array(
        [prediction[1] for prediction in predicted_set])
    low_predicted = np.array([prediction[0] for prediction in predicted_set])
    high_test = np.where(test_set == 'high', 1.0, 0.0)
    medium_test = np.where(test_set == 'medium', 1.0, 0.0)
    low_test = np.where(test_set == 'low', 1.0, 0.0)
    auc_high = roc_auc_score(high_test, high_predicted)
    auc_med = roc_auc_score(medium_test, medium_predicted)
    auc_low = roc_auc_score(low_test, low_predicted)
    auc_w = (low_test.sum() * auc_low + medium_test.sum() * auc_med +
             high_test.sum() * auc_high) / (
                 low_test.sum() + medium_test.sum() + high_test.sum())
    return auc_w


def evaluate(predicted_probabilities, y_test, labels, dataset_name):
    # Importante: al transformar los arreglos de probabilidad a clases,
    # entregar el arreglo de clases aprendido por el clasificador.
    # (que comunmente, es distinto a ['low', 'medium', 'high'])
    predicted_labels = [
        labels[np.argmax(item)] for item in predicted_probabilities
    ]
    print('Confusion Matrix for {}:\n'.format(dataset_name))
    print(
        confusion_matrix(y_test,
                         predicted_labels,
                         labels=['low', 'medium', 'high']))

#     print('\nClassification Report:\n')
#     print(
#         classification_report(y_test,
#                               predicted_labels,
#                               labels=['low', 'medium', 'high']))
    # Reorder predicted probabilities array.
    labels = labels.tolist()
    predicted_probabilities = predicted_probabilities[:, [
        labels.index('low'),
        labels.index('medium'),
        labels.index('high')
    ]]
    auc = round(auc_score(y_test, predicted_probabilities), 3)
    print("Scores:\n\nAUC: ", auc, end='\t')
    kappa = round(cohen_kappa_score(y_test, predicted_labels), 3)
    print("Kappa:", kappa, end='\t')
    accuracy = round(accuracy_score(y_test, predicted_labels), 3)
    print("Accuracy:", accuracy)
    print('------------------------------------------------------\n')
    return np.array([auc, kappa, accuracy])

# %% [markdown]
# ### Datos

# %%
# Datasets de entrenamiento.
train = {
    'anger': pd.read_csv('https://raw.githubusercontent.com/dccuchile/CC6205/master/assignments/assignment_1/data/train/anger-train.txt', sep='\t', names=['id', 'tweet', 'class', 'sentiment_intensity']),
    'fear': pd.read_csv('https://raw.githubusercontent.com/dccuchile/CC6205/master/assignments/assignment_1/data/train/fear-train.txt', sep='\t', names=['id', 'tweet', 'class', 'sentiment_intensity']),
    'joy': pd.read_csv('https://raw.githubusercontent.com/dccuchile/CC6205/master/assignments/assignment_1/data/train/joy-train.txt', sep='\t', names=['id', 'tweet', 'class', 'sentiment_intensity']),
    'sadness': pd.read_csv('https://raw.githubusercontent.com/dccuchile/CC6205/master/assignments/assignment_1/data/train/sadness-train.txt', sep='\t', names=['id', 'tweet', 'class', 'sentiment_intensity'])
}
# Datasets que deberán predecir para la competencia.
target = {
    'anger': pd.read_csv('https://raw.githubusercontent.com/dccuchile/CC6205/master/assignments/assignment_1/data/target/anger-target.txt', sep='\t', names=['id', 'tweet', 'class', 'sentiment_intensity'], na_values=['NONE']),
    'fear': pd.read_csv('https://raw.githubusercontent.com/dccuchile/CC6205/master/assignments/assignment_1/data/target/fear-target.txt', sep='\t', names=['id', 'tweet', 'class', 'sentiment_intensity'], na_values=['NONE']),
    'joy': pd.read_csv('https://raw.githubusercontent.com/dccuchile/CC6205/master/assignments/assignment_1/data/target/joy-target.txt', sep='\t', names=['id', 'tweet', 'class', 'sentiment_intensity'], na_values=['NONE']),
    'sadness': pd.read_csv('https://raw.githubusercontent.com/dccuchile/CC6205/master/assignments/assignment_1/data/target/sadness-target.txt', sep='\t', names=['id', 'tweet', 'class', 'sentiment_intensity'], na_values=['NONE'])
}

# %%
# Ejemplo de algunas filas aleatorias:
low_len, med_len, high_len = [], [], []
for index, row in train['fear'].iterrows():
    if row.sentiment_intensity=='low':
        low_len.append(len(row.tweet))
    if row.sentiment_intensity=='medium':
        med_len.append(len(row.tweet))
    if row.sentiment_intensity=='high':
        high_len.append(len(row.tweet))

# %% [markdown]
# ### Analizar los datos

# %%
def get_group_dist(group_name, train):
    print(group_name, "\n",
          train[group_name].groupby('sentiment_intensity').count(),
          '\n---------------------------------------\n')
for dataset_name in train:
    get_group_dist(dataset_name, train)
# Out:
# anger
#                        id  tweet  class
# sentiment_intensity
# high                 163    163    163
# low                  161    161    161
# medium               617    617    617
# ---------------------------------------
#
# fear
#                        id  tweet  class
# sentiment_intensity
# high                 270    270    270
# low                  288    288    288
# medium               699    699    699
# ---------------------------------------
#
# joy
#                        id  tweet  class
# sentiment_intensity
# high                 195    195    195
# low                  219    219    219
# medium               488    488    488
# ---------------------------------------
#
# sadness
#                        id  tweet  class
# sentiment_intensity
# high                 197    197    197
# low                  210    210    210
# medium               453    453    453
# ---------------------------------------

# %% [markdown]
# ### Custom Features
#
# Para crear features personalizadas implementaremos nuestros propios Transformers (estandar de scikit para crear nuevas features entre otras cosas). Para esto:
#
# 1. Creamos nuestra clase Transformer extendiendo BaseEstimator y TransformerMixin. En este ejemplo, definiremos `CharsCountTransformer` que cuenta carácteres relevantes ('!', '?', '#') en los tweets.
# 2. Definios una función cómo `get_relevant_chars` que opera por cada tweet y retorna un arreglo.
# 3. Hacemos un override de la función `transform` en donde iteramos por cada tweet, llamamos a la función que hicimos antes y agregamos sus resultados a un arrelo. Finalmente lo retornamos.
#
# Esto nos facilitará el trabajo mas adelante. Una Guia completa de las transformaciones predefinidas en scikit pueden encontrarla [aquí](https://scikit-learn.org/stable/data_transforms.html).

# %%
class BasicModelArchitecture:
    """
    Basic architecture of transformer classes, contains fit method.
    """
    def fit(self, X, y=None):
        return self

# %%
class CharsCountTransformer(BaseEstimator, TransformerMixin, BasicModelArchitecture):
    """
    Count relevant chars, emojis, repeated chars and dots, and do mark_negation.
    """
    def __init(self):
        super(CharsCountTransformer, self).__init__()
    
    def get_relevant_chars(self, tweet):
        num_hashtags = tweet.count('#')
        num_exclamations = tweet.count('!')
        num_interrogations = tweet.count('?')
        num_uppercases = sum(1 for c in tweet if c.isupper())  
        num_repeated_chars = self.count_repeated_chars(tweet)
        num_repeated_dots = self.count_repeated_dots(tweet)
        len_tweet = len(tweet)
        
        return [num_hashtags, num_exclamations, num_interrogations,
                num_uppercases, num_repeated_chars, num_repeated_dots, len_tweet]
    
    def get_emojis(self, tweet):
        """
        Get number, sentiment_score, and polarity of emojis.
        """
        emojis_list = [c for c in tweet if c in emoji.UNICODE_EMOJI]
        positive, negative, neutral, sent_score, type_pos, type_neg = 0, 0, 0, 0, 0, 0
        no_pesca = 0
        for emoj in emojis_list:
            try:
                em = get_emoji_sentiment_rank(emoj)
#                 positive += em['positive']
#                 negative += em['negative']
#                 neutral += em['neutral']
                sent_score += abs(em['sentiment_score'])
                if em['sentiment_score']>0:
                    type_pos += 1
                else:
                    type_neg += 1
                    
            # if get_emoji_sentiment_rank doesn't recognize the emoji
            except:  
                emoji_name = emoji.UNICODE_EMOJI.get(emoj)[1:-1]
                if emoji_name in positive_words:
                    type_pos += 1
                    continue
                elif emoji_name in negative_words:
                    type_neg += 1
                    continue
                else:
                    # Evaluate by words
                    for idx, w in enumerate(emoji_name.split('_')):
                        if w in positive_words:
                            type_pos += 1
                            break
                        elif w in negative_words:
                            type_neg += 1
                            break
        # Igual sigue trucho, porque solo considera la informacion de si el emoji es positivo o negativo
        # pero el emoji va a tener sent_score = 0, no seria tan comparable con los emojis que 
        # sí eran compatibles y no necesitaron esta trucheria, por lo que sí tienen sent_score
        return [len(emojis_list), sent_score, type_pos, type_neg]

    def neg_transform(self, X):
        """
        Append '_NEG' to all words after a negation.
        """
        converted = []
        counter = []
        for tweet in X:
            neg = mark_negation(tweet.split(' '))
            count = sum(1 for word in neg if neg[-4:]=='_NEG')
            sentence = ' '.join(word for word in neg)
            converted.append(sentence)
            counter.append(count)
        return count, converted
    
    def count_repeated_chars(self, tweet):
        """
        Count number of more than twice repeated chars ( >= three times).
        """
        c_prev = tweet[0]
        counter = 0
        twice = False
        for c in tweet[1:]:
            if c==c_prev:
                if twice:
                    counter += 1
                twice = True
            else:
                twice = False
            c_prev = c
        return counter
    
    def count_repeated_dots(self, tweet):
        """
        Count number of contiguous dots.
        """
        counter = 0
        prev_is_dot = False
        for c in tweet[1:]:
            if c == '.':
                if prev_is_dot:
                    counter += 1
                else:
                    prev_is_dot = True
            else:
                prev_is_dot = False
        return counter
    
    def transform(self, X, y=None):
        chars = []
        num_negs, X_neg = self.neg_transform(X)
        for tweet in X_neg:
            features = np.hstack((self.get_relevant_chars(tweet),
                                  self.get_emojis(tweet),
                                  num_negs))
            chars.append(features)
        return np.array(chars)

# %%
class LiuFeatureExtractor(BaseEstimator, TransformerMixin, BasicModelArchitecture):
    """
    Takes in a corpus of tweets and calculates features using Bing Liu's lexicon.
    """

    def __init__(self, tokenizer):
        super(LiuFeatureExtractor, self).__init__()
        self.tokenizer = tokenizer
        self.pos_set = set(opinion_lexicon.positive())
        self.neg_set = set(opinion_lexicon.negative())

    def liu_score(self,sentence):
        """
        Calculates the number of positive and negative words in the sentence using Bing Liu's Lexicon.
        """ 
        tokenized_sent = self.tokenizer.tokenize(sentence)
        pos_words = 0
        neg_words = 0
        for word in tokenized_sent:
            if word in self.pos_set:
                pos_words += 1
            elif word in self.neg_set:
                neg_words += 1
        return [pos_words,neg_words]

    def transform(self, X, y=None):
        """
        Applies liu_score on a data.frame containing tweets.
        """
        values = []
        for tweet in X:
            values.append(self.liu_score(tweet))

        return(np.array(values))

# %%
class VaderFeatureExtractor(BaseEstimator, TransformerMixin, BasicModelArchitecture):
    """
    Takes in a corpus of tweets and calculates features using the Vader method.
    """

    def __init__(self):
        super(VaderFeatureExtractor, self).__init__()
        self.sid = nltk.sentiment.SentimentIntensityAnalyzer()

    def transform(self, X, y=None):
        """
        Calculates sentiment scores for a sentence using the Vader method.
        """
        values = []
        for tweet in X:
            values.append(list(self.sid.polarity_scores(tweet).values()))

        return(np.array(values))

# %%
class TextBlobTransformer(BaseEstimator, TransformerMixin, BasicModelArchitecture):
    """
    Sentiment Analysis using TextBlob.
    """
    def __init__ (self):
        super(TextBlobTransformer, self).__init__()
    
    def transform(self, X, y=None):
        sent_pol = []
        for doc in X:
            correct = TextBlob(doc).correct().string
            sent_pol.append(TextBlob(correct).sentiment.polarity)
        return np.array([sent_pol]).T

# %%
# # Veamos que sucede si ejecutamos el transformer
# sample = train['joy'].sample(10).tweet
# print(sample)
# test = pd.DataFrame(zip(sample, TextBlobTransformer().transform(sample)))
# print(test.loc[0][1].mean())
# test

# %% [markdown]
# ## Doc2Vec

# %%
class Doc2VecTransformer(BaseEstimator, TransformerMixin, BasicModelArchitecture):
    """ Transforma tweets a representaciones vectoriales usando algún modelo de Word Embeddings.
    """
    
    def __init__(self, model, tokenizer, do_stem=False, do_lemmatize=False,
                 remove_stopwords=False):
        # extraemos los embeddings desde el objeto contenedor. ojo con esta parte.
        self.model = model.wv 
        self.tokenizer = tokenizer
        self.remove_stopwords = remove_stopwords
        self.do_stem = do_stem
        self.do_lemmatize = do_lemmatize
        

    def simple_tokenizer(self, doc, remove_stopwords=False, lower=False):
        """Tokenizador. Elimina signos de puntuación, lleva las letras a minúscula(opcional) y 
           separa el tweet por espacios.
        """
        tokens = self.tokenizer.tokenize(doc)
        final_tokens = []
        for t in tokens:
            try:
                if t[0]=='#':  # Convert hashtags
                    t = t[1:]
            except:
                print('Except', doc)
            if remove_stopwords:
                if t.lower() in stopwords:
                    continue
            if lower:
                t = t.lower()
            final_tokens.append(t)
        
        return final_tokens
    
    def stem(self, doc):  
        doc = stemmer.stem(doc)
        return doc
    
    def lemmatize(self, doc):        
        doc = lemmatizer.lemmatize(doc)
        return doc
        
    def transform(self, X, y=None):        
        doc_embeddings = []
        no_embeddings = False
        for doc in X:            
            tokens = self.simple_tokenizer(doc, self.remove_stopwords) 
    
            selected_wv = []
            sum_wv = []
            recognized = 0
            for token in tokens:
                token = token.lower()
                
                # Stem or lemmatize
                if self.do_stem:
                    token = self.stem(token)
                elif self.do_lemmatize:
                    token = self.lemmatize(token)
                
                
                if token in self.model.vocab:
                    recognized += 1
                    selected_wv.append(self.model[token])
                    
            selected_wv = np.array(selected_wv)        
            # si seleccionamos por lo menos un embedding para el tweet, lo agregamos y luego lo añadimos.
            if len(selected_wv) > 0:
                sum_wv = np.sum(selected_wv, axis=0)
                doc_embeddings.append(sum_wv/recognized)
            # si no, añadimos un vector de ceros que represente a ese documento.
            else: 
                if not no_embeddings:
                    print('Couldnt find any embedding for tweet:')
                    no_embeddings = True
                print(doc)
                doc_embeddings.append(np.zeros(self.model.vector_size)) # la dimension del modelo 

        return np.array(doc_embeddings)

# %% [markdown]
# ### Definir la representación y el clasificador

# %%
count = CountVectorizer(tokenizer=TweetTokenizer().tokenize,
                        ngram_range=(1, 4))

tfidf = TfidfVectorizer(tokenizer=TweetTokenizer().tokenize)

chars_count = CharsCountTransformer()

doc2vec_remove_stop = Doc2VecTransformer(glove_twitter, TweetTokenizer(), remove_stopwords=True)
doc2vec = Doc2VecTransformer(glove_twitter, TweetTokenizer())

doc2vec_stem = Doc2VecTransformer(glove_twitter, TweetTokenizer(), do_stem=True)
doc2vec_lem = Doc2VecTransformer(glove_twitter, TweetTokenizer(), do_lemmatize=True)

liu = LiuFeatureExtractor(tokenizer=TweetTokenizer())
vader = VaderFeatureExtractor()
textblob = TextBlobTransformer()
# Out:
# <ipython-input-17-f2e47b8e9edf>:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   self.model = model.wv

# %%
def get_experiment_0_pipeline():
    """
    CountVectorizer + NB
    """
    return Pipeline([('features',
                      FeatureUnion([('bow', count)
                                    ])), ('clf', MultinomialNB())])

# %%
def get_experiment_1_pipeline():
    """
    CountVectorizer + MLP
    """
    return Pipeline([('features',
                      FeatureUnion([('bow', count)])),
                     ('clf', MLPClassifier(hidden_layer_sizes=(30, 10)))])

# %%
def get_experiment_2_pipeline():
    """
    CountVectorizer + LR
    """
    return Pipeline([('features',
                      FeatureUnion([('bow', count)])),
                     ('clf', LogisticRegression(solver='liblinear',multi_class='ovr'))])

# %%
def get_experiment_3_pipeline():
    """
    CountVectorizer + CharsCountTransformer + NB
    """
    return Pipeline([('features',
                      FeatureUnion([('bow', count),
                                    ('chars_count', chars_count)
                                    ])), ('clf', LogisticRegression(solver='liblinear',multi_class='ovr'))])

# %%
def get_experiment_4_pipeline():
    """
    TfidfVectorizer + CharsCountTransformer + LR
    """
    return Pipeline([('features',
                      FeatureUnion([('tf-idf', tfidf),
                                    ('chars_count', chars_count)])),
                     ('clf', LogisticRegression(solver='liblinear',multi_class='ovr'))])

# %%
def get_experiment_5_pipeline():
    """
    TfidfVectorizer + Doc2Vec (removing stopwords) + LR
    """
    return Pipeline([('features',
                      FeatureUnion([('tf-idf', tfidf),
                                    ('doc2vec', doc2vec_remove_stop)])),
                     ('clf', LogisticRegression(solver='liblinear',multi_class='ovr'))])

# %%
def get_experiment_6_pipeline():
    """
    TfidfVectorizer + Doc2Vec (without removing stopwords) + LR
    """
    return Pipeline([('features',
                      FeatureUnion([('tf-idf', tfidf),
                                    ('doc2vec', doc2vec)])),
                     ('clf', LogisticRegression(solver='liblinear',multi_class='ovr'))])

# %%
def get_experiment_7_pipeline():
    """
    CountVectorizer + Doc2Vec (without removing stopwords) + LR
    """
    return Pipeline([('features',
                      FeatureUnion([('count', count),
                                    ('doc2vec', doc2vec)])),
                     ('clf', LogisticRegression(solver='liblinear',multi_class='ovr'))])

# %%
def get_experiment_8_pipeline():
    """
    TfidfVectorizer + Doc2Vec (with stemming) + LR
    """
    return Pipeline([('features',
                      FeatureUnion([('tf-idf', tfidf),
                                    ('doc2vec_stem', doc2vec_stem)])),
                     ('clf', LogisticRegression(solver='liblinear',multi_class='ovr'))])

# %%
def get_experiment_9_pipeline():
    """
    TfidfVectorizer + Doc2Vec (with lemmatization) + LR
    """
    return Pipeline([('features',
                      FeatureUnion([('tf-idf', tfidf),
                                    ('doc2vec_lem', doc2vec_lem)])),
                     ('clf', LogisticRegression(solver='liblinear',multi_class='ovr'))])

# %%
def get_experiment_10_pipeline():
    """
    CountVectorizer + CharsCountTransformer +  LiuFeatureExtractor + VaderFeatureExtractor + SVM
    """
    return Pipeline([('features',
                      FeatureUnion([('bow', count),
                                    ('chars_count', chars_count),
                                    ('liu', liu),
                                    ('vader', vader)
                                    ])), ('clf', SVC(probability=True))])

# %%
def get_experiment_11_pipeline():
    """
    CountVectorizer + CharsCountTransformer +  LiuFeatureExtractor + VaderFeatureExtractor + LR
    """
    return Pipeline([('features',
                      FeatureUnion([('bow', count),
                                    ('chars_count', chars_count),
                                    ('liu', liu),
                                    ('vader', vader)
                                    ])), ('clf', LogisticRegression(solver='liblinear',multi_class='ovr'))])

# %%
def get_experiment_12_pipeline():
    """
    CountVectorizer + CharsCountTransformer +  LiuFeatureExtractor + VaderFeatureExtractor + LR
    """
    return Pipeline([('features',
                      FeatureUnion([('bow', count),
                                    ('chars_count', chars_count),
                                    ('doc2vec', doc2vec),
                                    ('liu', liu),
                                    ('vader', vader)#,
#                                     ('textblob', textblob)
                                    ])), ('clf', LogisticRegression(solver='liblinear',multi_class='ovr'))])

# %%
def get_experiment_13_pipeline():
    """
    CountVectorizer + CharsCountTransformer +  LiuFeatureExtractor + VaderFeatureExtractor + doc2vec   
    featureSelection con LinearRegression + SVC
    """
    return Pipeline([('features',
                      FeatureUnion([('bow', count),
                                    ('chars_count', chars_count),
                                    ('doc2vec', doc2vec),
                                    ('liu', liu),
                                    ('vader', vader)#,
#                                     ('textblob', textblob),
                                    ])),
                     ('feature_selection',
                      SelectFromModel(LogisticRegression(solver='liblinear',multi_class='ovr'),
                                      threshold='median')),
                     ('clf', SVC(probability=True))])

# %% [markdown]
# ### Ejecutar el pipeline para algún dataset

# %%
def over_sampling(X, y):
    """
    Oversamplea unos datos al azar dependiendo si le faltan datos para igualar a la mayor
    """
    X_over = []
    y_over = []
    
    n_max = np.max([np.sum([y == c]) for c in np.unique(y)])
    
    for c in np.unique(y):
        n = n_max - np.sum([y == c])
        if n == 0: continue
        indices = np.where(y == c)[0]
        arr_sampling = np.random.randint(low=0,
                                         high=len(indices),
                                         size=int(n / 2))
        indices = np.array(indices[arr_sampling])
        
        X_over = np.concatenate([X_over, [X.iloc[i] for i in indices]])
        y_over = np.concatenate([y_over, [y.iloc[i] for i in indices]])
    
    X_over = np.concatenate([X, X_over])
    y_over = np.concatenate([y, y_over])
    
    return X_over, y_over

# %%
def run(dataset, dataset_name, pipeline):
    """
    Creamos el pipeline y luego lo ejecutamos el pipeline sobre un dataset. 
    Retorna el modelo ya entrenado mas sus labels asociadas y los scores obtenidos al evaluarlo.
    """
    
    scores = []
    
    dataset = dataset.sample(frac=1).reset_index()
    
    for n in range(3):

        i = int(n * len(dataset) / 3)
        j = int((n + 1) * len(dataset) / 3)
        X_test = dataset.tweet.iloc[i:j]
        y_test = dataset.sentiment_intensity.iloc[i:j]
        
        X_train = pd.concat([dataset.tweet.iloc[:i], dataset.tweet.iloc[j:]])
        y_train = pd.concat([dataset.sentiment_intensity.iloc[:i], dataset.sentiment_intensity.iloc[j:]])
        
        X_train, y_train = over_sampling(X_train, y_train)

        # Entrenamos el clasificador (Ejecuta el entrenamiento sobre todo el pipeline)
        pipeline.fit(X_train, y_train)

        # Predecimos las probabilidades de intensidad de cada elemento del set de prueba.
        predicted_probabilities = pipeline.predict_proba(X_test)

        # Obtenemos el orden de las clases aprendidas.
        learned_labels = pipeline.classes_

        # Evaluamos:
        scores.append(evaluate(predicted_probabilities, y_test, learned_labels, dataset_name))
    
    pipeline.fit(dataset.tweet, dataset.sentiment_intensity)
    
    return pipeline, learned_labels, np.array(scores).mean(axis=0)

# %% [markdown]
# ### Ejecutar el sistema creado por cada train set
#
# Este código crea y entrena los 4 sistemas de clasificación y luego los evalua. Para los experimentos, pueden copiar este código variando el pipeline cuantas veces estimen conveniente.

# %%
def run_experiments(experiments):
    best_scores = {
        'anger': 0,
        'fear': 0,
        'joy': 0,
        'sadness': 0
    }
    best_classifiers = {
        'anger': [],
        'fear': [],
        'joy': [],
        'sadness': []
    }

    for n, pipeline in enumerate(experiments):
        classifiers = []
        learned_labels_array = []
        scores_array = []

        # Por cada nombre_dataset, dataset en train ('anger', 'fear', 'joy', 'sadness')
        for dataset_name, dataset in train.items():
            print(dataset_name)
            # ejecutamos el pipeline sobre el dataset
            classifier, learned_labels, scores = run(dataset, dataset_name, pipeline)

            # guardamos el clasificador entrenado (en realidad es el pipeline ya entrenado...)
            classifiers.append(classifier)

            # guardamos las labels aprendidas por el clasificador
            learned_labels_array.append(learned_labels)

            # guardamos los scores obtenidos
            scores_array.append(scores)
            
            # encontramos el mejor clasificador para el dataset_name
            if np.sum(scores) > best_scores[dataset_name]:
                best_scores[dataset_name] = np.sum(scores)
                best_classifiers[dataset_name] = (classifier, n)

        # print avg scores
        print('Experiment', n,
          "Average scores:\n\n",
          "Average AUC: {0:.3g}\t Average Kappa: {1:.3g}\t Average Accuracy: {2:.3g}"
          .format(*np.array(scores_array).mean(axis=0)))
    return best_classifiers, best_scores

# %%
experiments = [get_experiment_0_pipeline(),
               get_experiment_1_pipeline(),
               get_experiment_2_pipeline(),
               get_experiment_3_pipeline(),
               get_experiment_4_pipeline(),               
               get_experiment_5_pipeline(),
               get_experiment_6_pipeline(),
               get_experiment_7_pipeline(),
               get_experiment_8_pipeline(),
               get_experiment_9_pipeline(),
               get_experiment_10_pipeline(),
               get_experiment_11_pipeline(),
               get_experiment_12_pipeline(),
               get_experiment_13_pipeline()]
# experiments = [get_experiment_10_pipeline(),
#                get_experiment_41_pipeline()]

# experiments = [get_experiment_102_pipeline()]

best_classifiers, best_scores = run_experiments(experiments)
# Out:
# anger
# Confusion Matrix for anger:
#
# [[  9  41   4]
#  [  8 159  34]
#  [  1  36  21]]
# Scores:
#
# AUC:  0.625	Kappa: 0.159	Accuracy: 0.604
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 12  45   2]
#  [ 11 161  36]
#  [  0  32  15]]
# Scores:
#
# AUC:  0.572	Kappa: 0.126	Accuracy: 0.599
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 14  33   1]
#  [ 15 174  19]
#  [  0  39  19]]
# Scores:
#
# AUC:  0.602	Kappa: 0.232	Accuracy: 0.659
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 33  60   7]
#  [ 27 165  36]
#  [  3  44  44]]
# Scores:
#
# AUC:  0.659	Kappa: 0.258	Accuracy: 0.578
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 34  49   3]
#  [ 35 179  26]
#  [  4  58  31]]
# Scores:
#
# AUC:  0.622	Kappa: 0.229	Accuracy: 0.582
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 37  49  16]
#  [ 20 173  38]
#  [  3  49  34]]
# Scores:
#
# AUC:  0.642	Kappa: 0.261	Accuracy: 0.582
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 31  48   2]
#  [ 33 104  14]
#  [  2  33  33]]
# Scores:
#
# AUC:  0.688	Kappa: 0.258	Accuracy: 0.56
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 26  40   2]
#  [ 19 136  20]
#  [  3  20  35]]
# Scores:
#
# AUC:  0.728	Kappa: 0.371	Accuracy: 0.654
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 21  47   2]
#  [ 16 132  14]
#  [  0  33  36]]
# Scores:
#
# AUC:  0.732	Kappa: 0.327	Accuracy: 0.628
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[ 16  48   1]
#  [ 12 126  14]
#  [  1  47  21]]
# Scores:
#
# AUC:  0.619	Kappa: 0.197	Accuracy: 0.57
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 19  45   2]
#  [ 22 125  11]
#  [  4  39  20]]
# Scores:
#
# AUC:  0.633	Kappa: 0.203	Accuracy: 0.571
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 22  54   3]
#  [ 16 111  16]
#  [  1  46  18]]
# Scores:
#
# AUC:  0.655	Kappa: 0.164	Accuracy: 0.526
# ------------------------------------------------------
#
# Experiment 0 Average scores:
#
#  Average AUC: 0.648	 Average Kappa: 0.232	 Average Accuracy: 0.593
# anger
# Confusion Matrix for anger:
#
# [[ 13  40   0]
#  [ 28 162  14]
#  [  6  37  13]]
# Scores:
#
# AUC:  0.558	Kappa: 0.135	Accuracy: 0.601
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  8  41   0]
#  [ 10 191   7]
#  [  0  48   9]]
# Scores:
#
# AUC:  0.619	Kappa: 0.137	Accuracy: 0.662
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 11  47   1]
#  [ 11 174  20]
#  [  0  30  20]]
# Scores:
#
# AUC:  0.626	Kappa: 0.218	Accuracy: 0.653
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 33  70   5]
#  [ 31 181  17]
#  [  4  58  20]]
# Scores:
#
# AUC:  0.648	Kappa: 0.175	Accuracy: 0.558
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 19  69   3]
#  [ 20 198  15]
#  [  3  73  19]]
# Scores:
#
# AUC:  0.616	Kappa: 0.138	Accuracy: 0.563
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 46  42   1]
#  [ 57 165  15]
#  [ 20  50  23]]
# Scores:
#
# AUC:  0.653	Kappa: 0.225	Accuracy: 0.558
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[  9  62   0]
#  [ 10 149   3]
#  [  1  44  22]]
# Scores:
#
# AUC:  0.702	Kappa: 0.21	Accuracy: 0.6
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 11  65   0]
#  [  4 157  10]
#  [  2  32  20]]
# Scores:
#
# AUC:  0.688	Kappa: 0.231	Accuracy: 0.625
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[22 49  1]
#  [44 95 16]
#  [ 9 36 29]]
# Scores:
#
# AUC:  0.653	Kappa: 0.134	Accuracy: 0.485
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[14 39 14]
#  [15 85 42]
#  [ 2 25 50]]
# Scores:
#
# AUC:  0.64	Kappa: 0.223	Accuracy: 0.521
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 13  60   5]
#  [ 14 114  19]
#  [  4  39  19]]
# Scores:
#
# AUC:  0.578	Kappa: 0.12	Accuracy: 0.509
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[  6  56   3]
#  [ 13 133  18]
#  [  1  35  22]]
# Scores:
#
# AUC:  0.601	Kappa: 0.136	Accuracy: 0.561
# ------------------------------------------------------
#
# Experiment 1 Average scores:
#
#  Average AUC: 0.632	 Average Kappa: 0.173	 Average Accuracy: 0.575
# anger
# Confusion Matrix for anger:
#
# [[  6  46   0]
#  [  5 194  10]
#  [  2  37  13]]
# Scores:
#
# AUC:  0.628	Kappa: 0.181	Accuracy: 0.681
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  4  47   0]
#  [ 10 184  11]
#  [  0  48  10]]
# Scores:
#
# AUC:  0.564	Kappa: 0.077	Accuracy: 0.631
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  6  52   0]
#  [ 11 180  12]
#  [  0  39  14]]
# Scores:
#
# AUC:  0.599	Kappa: 0.132	Accuracy: 0.637
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 26  73   4]
#  [ 18 197  23]
#  [  4  46  28]]
# Scores:
#
# AUC:  0.662	Kappa: 0.227	Accuracy: 0.599
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 21  62   4]
#  [ 19 202  18]
#  [  2  57  34]]
# Scores:
#
# AUC:  0.69	Kappa: 0.246	Accuracy: 0.613
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 22  76   0]
#  [ 16 191  15]
#  [  2  71  26]]
# Scores:
#
# AUC:  0.684	Kappa: 0.185	Accuracy: 0.57
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 21  49   3]
#  [ 11 136  15]
#  [  3  30  32]]
# Scores:
#
# AUC:  0.73	Kappa: 0.325	Accuracy: 0.63
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 20  46   1]
#  [ 16 141  11]
#  [  2  38  26]]
# Scores:
#
# AUC:  0.709	Kappa: 0.281	Accuracy: 0.621
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 23  56   0]
#  [ 13 135  10]
#  [  1  33  30]]
# Scores:
#
# AUC:  0.71	Kappa: 0.316	Accuracy: 0.625
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[  6  63   6]
#  [  5 120  15]
#  [  4  43  24]]
# Scores:
#
# AUC:  0.645	Kappa: 0.151	Accuracy: 0.524
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[  7  61   3]
#  [ 10 128  10]
#  [  2  49  17]]
# Scores:
#
# AUC:  0.635	Kappa: 0.115	Accuracy: 0.53
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 18  41   5]
#  [ 22 129  14]
#  [  4  29  25]]
# Scores:
#
# AUC:  0.648	Kappa: 0.253	Accuracy: 0.599
# ------------------------------------------------------
#
# Experiment 2 Average scores:
#
#  Average AUC: 0.659	 Average Kappa: 0.207	 Average Accuracy: 0.605
# anger
# Confusion Matrix for anger:
#
# [[ 10  49   2]
#  [ 13 175  11]
#  [  0  42  11]]
# Scores:
#
# AUC:  0.604	Kappa: 0.135	Accuracy: 0.626
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  7  47   0]
#  [ 11 182  10]
#  [  2  40  15]]
# Scores:
#
# AUC:  0.63	Kappa: 0.167	Accuracy: 0.65
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  7  38   1]
#  [  5 199  11]
#  [  1  38  14]]
# Scores:
#
# AUC:  0.647	Kappa: 0.213	Accuracy: 0.701
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 28  71   3]
#  [ 20 193  15]
#  [  3  66  20]]
# Scores:
#
# AUC:  0.664	Kappa: 0.187	Accuracy: 0.575
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 25  50   4]
#  [ 35 188  20]
#  [ 11  59  27]]
# Scores:
#
# AUC:  0.669	Kappa: 0.192	Accuracy: 0.573
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 28  74   5]
#  [ 20 184  24]
#  [  4  58  22]]
# Scores:
#
# AUC:  0.654	Kappa: 0.172	Accuracy: 0.558
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 19  44   0]
#  [ 26 138  15]
#  [  1  28  29]]
# Scores:
#
# AUC:  0.708	Kappa: 0.272	Accuracy: 0.62
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 23  55   3]
#  [ 18 128  11]
#  [  1  37  25]]
# Scores:
#
# AUC:  0.726	Kappa: 0.251	Accuracy: 0.585
# ------------------------------------------------------
# Confusion Matrix for joy:
#
# [[ 27  47   1]
#  [ 14 131   7]
#  [  3  40  31]]
# Scores:
#
# AUC:  0.73	Kappa: 0.343	Accuracy: 0.628
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[ 10  65   3]
#  [ 11 118  14]
#  [  1  46  18]]
# Scores:
#
# AUC:  0.651	Kappa: 0.111	Accuracy: 0.51
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 16  43   3]
#  [ 15 124  16]
#  [  7  37  26]]
# Scores:
#
# AUC:  0.676	Kappa: 0.232	Accuracy: 0.578
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[  3  61   6]
#  [  7 129  19]
#  [  4  40  18]]
# Scores:
#
# AUC:  0.612	Kappa: 0.087	Accuracy: 0.523
# ------------------------------------------------------
#
# Experiment 3 Average scores:
#
#  Average AUC: 0.664	 Average Kappa: 0.197	 Average Accuracy: 0.594
# anger
# Confusion Matrix for anger:
#
# [[ 16  41   1]
#  [ 13 173  16]
#  [  0  38  15]]
# Scores:
#
# AUC:  0.634	Kappa: 0.219	Accuracy: 0.652
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 12  32   3]
#  [ 17 176  21]
#  [  4  31  18]]
# Scores:
#
# AUC:  0.642	Kappa: 0.224	Accuracy: 0.656
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  7  45   4]
#  [ 14 172  15]
#  [  1  41  15]]
# Scores:
#
# AUC:  0.616	Kappa: 0.135	Accuracy: 0.618
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 32  68   0]
#  [ 25 182  17]
#  [  9  57  29]]
# Scores:
#
# AUC:  0.657	Kappa: 0.23	Accuracy: 0.58
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 38  53   9]
#  [ 41 174  27]
#  [ 12  35  30]]
# Scores:
#
# AUC:  0.666	Kappa: 0.243	Accuracy: 0.578
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 32  50   6]
#  [ 29 177  27]
#  [  6  54  38]]
# Scores:
#
# AUC:  0.678	Kappa: 0.259	Accuracy: 0.589
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 31  30   4]
#  [ 35 106  26]
#  [  2  32  34]]
# Scores:
#
# AUC:  0.683	Kappa: 0.272	Accuracy: 0.57
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 35  41   2]
#  [ 33 108  16]
#  [  2  29  35]]
# Scores:
#
# AUC:  0.727	Kappa: 0.311	Accuracy: 0.591
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[25 50  1]
#  [33 99 32]
#  [ 0 22 39]]
# Scores:
#
# AUC:  0.689	Kappa: 0.227	Accuracy: 0.542
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[ 22  37   3]
#  [ 17 121  16]
#  [  5  40  25]]
# Scores:
#
# AUC:  0.706	Kappa: 0.258	Accuracy: 0.587
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 21  43   7]
#  [ 22 106  22]
#  [  2  35  29]]
# Scores:
#
# AUC:  0.69	Kappa: 0.213	Accuracy: 0.544
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 21  52   4]
#  [ 17 110  22]
#  [  8  23  30]]
# Scores:
#
# AUC:  0.66	Kappa: 0.244	Accuracy: 0.561
# ------------------------------------------------------
#
# Experiment 4 Average scores:
#
#  Average AUC: 0.671	 Average Kappa: 0.236	 Average Accuracy: 0.589
# anger
# Couldnt find any embedding for tweet:
# I can't even right now #bb18
# I think they may be
# Confusion Matrix for anger:
#
# [[ 21  29   3]
#  [ 22 170  21]
#  [  2  26  19]]
# Scores:
#
# AUC:  0.683	Kappa: 0.294	Accuracy: 0.671
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# I can't even right now #bb18
# I think they may be
# I think they may be
# Confusion Matrix for anger:
#
# [[ 25  29   4]
#  [ 26 144  29]
#  [  2  27  28]]
# Scores:
#
# AUC:  0.69	Kappa: 0.297	Accuracy: 0.627
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# I can't even right now #bb18
# I think they may be
# I think they may be
# I think they may be
# Confusion Matrix for anger:
#
# [[ 18  30   2]
#  [ 16 161  28]
#  [  1  33  25]]
# Scores:
#
# AUC:  0.673	Kappa: 0.276	Accuracy: 0.65
# ------------------------------------------------------
#
# fear
# Couldnt find any embedding for tweet:
# And here we go again 😓
# That goes the
# Confusion Matrix for fear:
#
# [[ 41  46   3]
#  [ 38 159  31]
#  [  7  41  53]]
# Scores:
#
# AUC:  0.726	Kappa: 0.324	Accuracy: 0.604
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# That goes the
# Couldnt find any embedding for tweet:
# And here we go again 😓
# Confusion Matrix for fear:
#
# [[ 43  54   8]
#  [ 31 163  36]
#  [  4  41  39]]
# Scores:
#
# AUC:  0.697	Kappa: 0.279	Accuracy: 0.585
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# And here we go again 😓
# Couldnt find any embedding for tweet:
# That goes the
# Confusion Matrix for fear:
#
# [[ 46  41   6]
#  [ 50 156  35]
#  [  9  27  49]]
# Scores:
#
# AUC:  0.734	Kappa: 0.324	Accuracy: 0.599
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 44  17   1]
#  [ 42 102  23]
#  [  3  32  36]]
# Scores:
#
# AUC:  0.728	Kappa: 0.356	Accuracy: 0.607
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[34 43  3]
#  [28 96 32]
#  [ 2 18 45]]
# Scores:
#
# AUC:  0.747	Kappa: 0.32	Accuracy: 0.581
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 39  31   7]
#  [ 34 101  30]
#  [  4  22  33]]
# Scores:
#
# AUC:  0.734	Kappa: 0.301	Accuracy: 0.575
# ------------------------------------------------------
#
# sadness
# Couldnt find any embedding for tweet:
# @chelseafc let them know it's the
# @chelseafc let them know it's the
# Confusion Matrix for sadness:
#
# [[ 24  37   3]
#  [ 34 101  19]
#  [ 10  26  32]]
# Scores:
#
# AUC:  0.698	Kappa: 0.24	Accuracy: 0.549
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# @chelseafc let them know it's the
# Confusion Matrix for sadness:
#
# [[ 32  34   4]
#  [ 26 107  17]
#  [  7  34  26]]
# Scores:
#
# AUC:  0.701	Kappa: 0.277	Accuracy: 0.575
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# @chelseafc let them know it's the
# Confusion Matrix for sadness:
#
# [[24 46  6]
#  [18 99 32]
#  [ 4 26 32]]
# Scores:
#
# AUC:  0.679	Kappa: 0.228	Accuracy: 0.54
# ------------------------------------------------------
#
# Experiment 5 Average scores:
#
#  Average AUC: 0.708	 Average Kappa: 0.293	 Average Accuracy: 0.597
# anger
# Confusion Matrix for anger:
#
# [[ 11  32   0]
#  [ 27 166  24]
#  [  1  33  19]]
# Scores:
#
# AUC:  0.637	Kappa: 0.166	Accuracy: 0.626
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 15  33   5]
#  [ 27 154  24]
#  [  2  32  22]]
# Scores:
#
# AUC:  0.652	Kappa: 0.204	Accuracy: 0.608
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 20  45   0]
#  [ 17 161  17]
#  [  1  36  17]]
# Scores:
#
# AUC:  0.699	Kappa: 0.227	Accuracy: 0.631
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 48  39   8]
#  [ 25 170  42]
#  [  3  44  40]]
# Scores:
#
# AUC:  0.73	Kappa: 0.329	Accuracy: 0.616
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 38  51   5]
#  [ 40 160  30]
#  [ 11  46  38]]
# Scores:
#
# AUC:  0.68	Kappa: 0.242	Accuracy: 0.563
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 35  58   6]
#  [ 33 159  40]
#  [  5  37  46]]
# Scores:
#
# AUC:  0.694	Kappa: 0.26	Accuracy: 0.573
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 36  36   4]
#  [ 26 110  22]
#  [  2  21  43]]
# Scores:
#
# AUC:  0.771	Kappa: 0.386	Accuracy: 0.63
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 42  23   4]
#  [ 38 107  31]
#  [  9  11  36]]
# Scores:
#
# AUC:  0.723	Kappa: 0.373	Accuracy: 0.615
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 31  37   6]
#  [ 28 104  22]
#  [  3  21  49]]
# Scores:
#
# AUC:  0.746	Kappa: 0.365	Accuracy: 0.611
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[ 23  38   4]
#  [ 20 112  22]
#  [  4  28  35]]
# Scores:
#
# AUC:  0.7	Kappa: 0.298	Accuracy: 0.594
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 22  45   7]
#  [ 16 117  20]
#  [  7  32  21]]
# Scores:
#
# AUC:  0.688	Kappa: 0.216	Accuracy: 0.557
# ------------------------------------------------------
# Confusion Matrix for sadness:
#
# [[38 28  5]
#  [30 98 18]
#  [ 6 35 29]]
# Scores:
#
# AUC:  0.705	Kappa: 0.299	Accuracy: 0.575
# ------------------------------------------------------
#
# Experiment 6 Average scores:
#
#  Average AUC: 0.702	 Average Kappa: 0.28	 Average Accuracy: 0.6
# anger
# Confusion Matrix for anger:
#
# [[  7  34   0]
#  [ 17 193  11]
#  [  0  41  10]]
# Scores:
#
# AUC:  0.663	Kappa: 0.121	Accuracy: 0.671
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 10  50   1]
#  [ 12 174   8]
#  [  0  47  12]]
# Scores:
#
# AUC:  0.659	Kappa: 0.147	Accuracy: 0.624
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 11  47   1]
#  [  7 184  11]
#  [  0  37  16]]
# Scores:
#
# AUC:  0.613	Kappa: 0.228	Accuracy: 0.672
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 32  66   6]
#  [ 29 180  22]
#  [  3  46  35]]
# Scores:
#
# AUC:  0.678	Kappa: 0.251	Accuracy: 0.589
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 33  57   3]
#  [ 22 195  16]
#  [  3  62  28]]
# Scores:
#
# AUC:  0.681	Kappa: 0.263	Accuracy: 0.611
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 25  65   1]
#  [ 26 190  19]
#  [  5  58  30]]
# Scores:
#
# AUC:  0.682	Kappa: 0.21	Accuracy: 0.585
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 17  50   3]
#  [ 12 142  10]
#  [  0  38  28]]
# Scores:
#
# AUC:  0.709	Kappa: 0.287	Accuracy: 0.623
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 20  60   1]
#  [ 15 131  14]
#  [  1  33  26]]
# Scores:
#
# AUC:  0.712	Kappa: 0.244	Accuracy: 0.588
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 22  46   0]
#  [ 19 132  13]
#  [  2  32  35]]
# Scores:
#
# AUC:  0.718	Kappa: 0.325	Accuracy: 0.628
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[ 12  56   5]
#  [ 16 121  19]
#  [  0  36  21]]
# Scores:
#
# AUC:  0.634	Kappa: 0.141	Accuracy: 0.538
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[  7  59   1]
#  [ 15 112  14]
#  [  2  58  19]]
# Scores:
#
# AUC:  0.654	Kappa: 0.066	Accuracy: 0.481
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 18  47   5]
#  [ 16 124  16]
#  [ 10  26  25]]
# Scores:
#
# AUC:  0.68	Kappa: 0.247	Accuracy: 0.582
# ------------------------------------------------------
#
# Experiment 7 Average scores:
#
#  Average AUC: 0.674	 Average Kappa: 0.211	 Average Accuracy: 0.599
# anger
# Confusion Matrix for anger:
#
# [[ 20  34   0]
#  [ 25 151  21]
#  [  2  41  19]]
# Scores:
#
# AUC:  0.654	Kappa: 0.205	Accuracy: 0.607
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 22  30   4]
#  [ 28 158  28]
#  [  2  30  12]]
# Scores:
#
# AUC:  0.636	Kappa: 0.187	Accuracy: 0.611
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 17  33   1]
#  [ 18 171  17]
#  [  2  35  20]]
# Scores:
#
# AUC:  0.688	Kappa: 0.265	Accuracy: 0.662
# ------------------------------------------------------
#
# fear
# Couldnt find any embedding for tweet:
# Overtime... #TeamNA #WCH2016
# Confusion Matrix for fear:
#
# [[ 33  45   4]
#  [ 29 182  30]
#  [ 12  42  42]]
# Scores:
#
# AUC:  0.681	Kappa: 0.303	Accuracy: 0.613
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# Overtime... #TeamNA #WCH2016
# Confusion Matrix for fear:
#
# [[ 40  51   8]
#  [ 35 168  32]
#  [  3  48  34]]
# Scores:
#
# AUC:  0.676	Kappa: 0.249	Accuracy: 0.578
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# Overtime... #TeamNA #WCH2016
# Confusion Matrix for fear:
#
# [[ 38  62   7]
#  [ 27 162  34]
#  [  8  50  31]]
# Scores:
#
# AUC:  0.676	Kappa: 0.214	Accuracy: 0.551
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 34  40   1]
#  [ 28 114  19]
#  [  4  24  36]]
# Scores:
#
# AUC:  0.711	Kappa: 0.341	Accuracy: 0.613
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 28  38   2]
#  [ 23 117  23]
#  [  4  25  41]]
# Scores:
#
# AUC:  0.764	Kappa: 0.346	Accuracy: 0.618
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 33  36   7]
#  [ 31 101  32]
#  [  2  23  36]]
# Scores:
#
# AUC:  0.708	Kappa: 0.28	Accuracy: 0.565
# ------------------------------------------------------
#
# sadness
# Couldnt find any embedding for tweet:
# @Christy_RTR @doge_e_fresh I'm despondent
# Confusion Matrix for sadness:
#
# [[ 18  46   8]
#  [ 20 112  20]
#  [  2  32  28]]
# Scores:
#
# AUC:  0.658	Kappa: 0.214	Accuracy: 0.552
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# @Christy_RTR @doge_e_fresh I'm despondent
# @Christy_RTR @doge_e_fresh I'm despondent
# Confusion Matrix for sadness:
#
# [[ 25  34   4]
#  [ 25 110  20]
#  [  9  32  28]]
# Scores:
#
# AUC:  0.688	Kappa: 0.255	Accuracy: 0.568
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# @Christy_RTR @doge_e_fresh I'm despondent
# Confusion Matrix for sadness:
#
# [[ 27  45   3]
#  [ 19 118   9]
#  [  6  30  30]]
# Scores:
#
# AUC:  0.701	Kappa: 0.324	Accuracy: 0.61
# ------------------------------------------------------
#
# Experiment 8 Average scores:
#
#  Average AUC: 0.687	 Average Kappa: 0.265	 Average Accuracy: 0.596
# anger
# Confusion Matrix for anger:
#
# [[ 18  40   1]
#  [ 26 157  22]
#  [  1  29  19]]
# Scores:
#
# AUC:  0.681	Kappa: 0.206	Accuracy: 0.62
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 22  22   2]
#  [ 39 152  26]
#  [  2  27  22]]
# Scores:
#
# AUC:  0.65	Kappa: 0.252	Accuracy: 0.624
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 20  30   6]
#  [ 14 156  25]
#  [  0  40  23]]
# Scores:
#
# AUC:  0.673	Kappa: 0.266	Accuracy: 0.634
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 40  58   9]
#  [ 33 160  32]
#  [  4  44  39]]
# Scores:
#
# AUC:  0.711	Kappa: 0.256	Accuracy: 0.57
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 38  43   6]
#  [ 30 180  35]
#  [  4  38  45]]
# Scores:
#
# AUC:  0.714	Kappa: 0.332	Accuracy: 0.628
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 39  51   4]
#  [ 26 166  37]
#  [  3  42  51]]
# Scores:
#
# AUC:  0.711	Kappa: 0.324	Accuracy: 0.611
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[31 45  3]
#  [31 94 28]
#  [ 5 24 39]]
# Scores:
#
# AUC:  0.693	Kappa: 0.258	Accuracy: 0.547
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 36  25   4]
#  [ 35 117  18]
#  [  4  27  35]]
# Scores:
#
# AUC:  0.736	Kappa: 0.361	Accuracy: 0.625
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 35  32   8]
#  [ 29 112  24]
#  [  1  16  44]]
# Scores:
#
# AUC:  0.766	Kappa: 0.395	Accuracy: 0.635
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[ 24  38   9]
#  [ 14 121  26]
#  [  3  23  28]]
# Scores:
#
# AUC:  0.697	Kappa: 0.3	Accuracy: 0.605
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 26  43   4]
#  [ 21 107  19]
#  [ 10  26  31]]
# Scores:
#
# AUC:  0.7	Kappa: 0.275	Accuracy: 0.571
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 22  42   2]
#  [ 22 110  13]
#  [  1  49  26]]
# Scores:
#
# AUC:  0.662	Kappa: 0.215	Accuracy: 0.551
# ------------------------------------------------------
#
# Experiment 9 Average scores:
#
#  Average AUC: 0.699	 Average Kappa: 0.287	 Average Accuracy: 0.602
# anger
# Confusion Matrix for anger:
#
# [[  7  45   2]
#  [  7 180  13]
#  [  3  50   6]]
# Scores:
#
# AUC:  0.557	Kappa: 0.08	Accuracy: 0.617
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  0  50   7]
#  [  0 200  14]
#  [  0  36   7]]
# Scores:
#
# AUC:  0.571	Kappa: 0.072	Accuracy: 0.659
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  6  43   1]
#  [ 14 183   6]
#  [  2  51   8]]
# Scores:
#
# AUC:  0.631	Kappa: 0.09	Accuracy: 0.627
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 12  73   9]
#  [ 20 182  37]
#  [  9  67  10]]
# Scores:
#
# AUC:  0.537	Kappa: -0.002	Accuracy: 0.487
# ------------------------------------------------------
# Confusion Matrix for fear:
#
# [[ 26  68   4]
#  [ 29 174  24]
#  [  7  62  25]]
# Scores:
#
# AUC:  0.608	Kappa: 0.149	Accuracy: 0.537
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 10  84   2]
#  [ 21 192  20]
#  [  8  60  22]]
# Scores:
#
# AUC:  0.587	Kappa: 0.088	Accuracy: 0.535
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[  0  72   3]
#  [  3 140  19]
#  [  0  32  31]]
# Scores:
#
# AUC:  0.615	Kappa: 0.175	Accuracy: 0.57
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[  8  60   6]
#  [ 16 142  16]
#  [  1  30  22]]
# Scores:
#
# AUC:  0.574	Kappa: 0.157	Accuracy: 0.571
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[  0  66   4]
#  [  0 125  27]
#  [  2  37  40]]
# Scores:
#
# AUC:  0.645	Kappa: 0.184	Accuracy: 0.548
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[  9  61  13]
#  [  9 118  19]
#  [  3  43  11]]
# Scores:
#
# AUC:  0.573	Kappa: 0.063	Accuracy: 0.483
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[  4  46  13]
#  [  2 122  31]
#  [  1  43  25]]
# Scores:
#
# AUC:  0.609	Kappa: 0.122	Accuracy: 0.526
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 15  46   3]
#  [  8 130  14]
#  [  4  53  14]]
# Scores:
#
# AUC:  0.669	Kappa: 0.158	Accuracy: 0.554
# ------------------------------------------------------
#
# Experiment 10 Average scores:
#
#  Average AUC: 0.598	 Average Kappa: 0.111	 Average Accuracy: 0.559
# anger
# Confusion Matrix for anger:
#
# [[ 10  44   0]
#  [  8 189   8]
#  [  0  45   9]]
# Scores:
#
# AUC:  0.669	Kappa: 0.159	Accuracy: 0.665
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  7  47   3]
#  [ 12 180  11]
#  [  1  43  10]]
# Scores:
#
# AUC:  0.653	Kappa: 0.112	Accuracy: 0.627
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 12  36   2]
#  [ 16 183  10]
#  [  2  38  15]]
# Scores:
#
# AUC:  0.708	Kappa: 0.221	Accuracy: 0.669
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 36  48   3]
#  [ 24 193  16]
#  [  6  65  28]]
# Scores:
#
# AUC:  0.689	Kappa: 0.277	Accuracy: 0.613
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 39  58   1]
#  [ 29 187  23]
#  [  6  49  27]]
# Scores:
#
# AUC:  0.705	Kappa: 0.259	Accuracy: 0.604
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 38  61   4]
#  [ 23 182  22]
#  [  3  51  35]]
# Scores:
#
# AUC:  0.71	Kappa: 0.29	Accuracy: 0.609
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 31  39   3]
#  [ 19 122  21]
#  [  3  31  31]]
# Scores:
#
# AUC:  0.751	Kappa: 0.324	Accuracy: 0.613
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 34  41   2]
#  [ 18 129  11]
#  [  2  37  27]]
# Scores:
#
# AUC:  0.744	Kappa: 0.346	Accuracy: 0.631
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 34  34   1]
#  [ 29 129  10]
#  [  0  38  26]]
# Scores:
#
# AUC:  0.756	Kappa: 0.327	Accuracy: 0.628
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[ 15  46   3]
#  [ 23 115  13]
#  [  9  40  22]]
# Scores:
#
# AUC:  0.673	Kappa: 0.162	Accuracy: 0.531
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 22  47   3]
#  [ 14 126  15]
#  [  5  31  24]]
# Scores:
#
# AUC:  0.69	Kappa: 0.271	Accuracy: 0.599
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 22  46   6]
#  [ 14 114  19]
#  [  1  36  29]]
# Scores:
#
# AUC:  0.68	Kappa: 0.259	Accuracy: 0.575
# ------------------------------------------------------
#
# Experiment 11 Average scores:
#
#  Average AUC: 0.702	 Average Kappa: 0.251	 Average Accuracy: 0.614
# anger
# Confusion Matrix for anger:
#
# [[  9  47   0]
#  [  8 186  16]
#  [  0  34  13]]
# Scores:
#
# AUC:  0.676	Kappa: 0.17	Accuracy: 0.665
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 17  40   1]
#  [ 16 168  10]
#  [  0  45  17]]
# Scores:
#
# AUC:  0.663	Kappa: 0.233	Accuracy: 0.643
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 14  33   0]
#  [ 18 181  14]
#  [  1  45   8]]
# Scores:
#
# AUC:  0.688	Kappa: 0.143	Accuracy: 0.646
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 33  56   3]
#  [ 22 192  22]
#  [  7  49  35]]
# Scores:
#
# AUC:  0.729	Kappa: 0.294	Accuracy: 0.621
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 34  49   3]
#  [ 45 174  20]
#  [  9  59  26]]
# Scores:
#
# AUC:  0.657	Kappa: 0.192	Accuracy: 0.558
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 42  62   6]
#  [ 29 171  24]
#  [  3  55  27]]
# Scores:
#
# AUC:  0.697	Kappa: 0.235	Accuracy: 0.573
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 40  40   3]
#  [ 23 128  10]
#  [  3  26  27]]
# Scores:
#
# AUC:  0.765	Kappa: 0.383	Accuracy: 0.65
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 31  38   1]
#  [ 17 129  17]
#  [  2  26  40]]
# Scores:
#
# AUC:  0.763	Kappa: 0.412	Accuracy: 0.664
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 31  33   2]
#  [ 23 123  18]
#  [  2  38  31]]
# Scores:
#
# AUC:  0.763	Kappa: 0.322	Accuracy: 0.615
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[ 17  53   6]
#  [ 14 100  11]
#  [  6  51  28]]
# Scores:
#
# AUC:  0.705	Kappa: 0.188	Accuracy: 0.507
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 28  38   3]
#  [ 22 115  17]
#  [  2  33  29]]
# Scores:
#
# AUC:  0.699	Kappa: 0.298	Accuracy: 0.599
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 24  38   3]
#  [ 20 125  29]
#  [  4  20  24]]
# Scores:
#
# AUC:  0.676	Kappa: 0.268	Accuracy: 0.603
# ------------------------------------------------------
#
# Experiment 12 Average scores:
#
#  Average AUC: 0.707	 Average Kappa: 0.262	 Average Accuracy: 0.612
# anger
# Confusion Matrix for anger:
#
# [[ 11  45   0]
#  [  9 173  18]
#  [  0  47  10]]
# Scores:
#
# AUC:  0.567	Kappa: 0.118	Accuracy: 0.62
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  8  39   0]
#  [ 11 191  12]
#  [  0  44   9]]
# Scores:
#
# AUC:  0.688	Kappa: 0.123	Accuracy: 0.662
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  0  57   1]
#  [  0 199   4]
#  [  0  50   3]]
# Scores:
#
# AUC:  0.565	Kappa: 0.025	Accuracy: 0.643
# ------------------------------------------------------
#
# fear
# Confusion Matrix for fear:
#
# [[ 19  92   0]
#  [ 16 199  11]
#  [  2  61  19]]
# Scores:
#
# AUC:  0.711	Kappa: 0.147	Accuracy: 0.566
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 30  59   6]
#  [ 26 174  37]
#  [  4  65  18]]
# Scores:
#
# AUC:  0.604	Kappa: 0.121	Accuracy: 0.53
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 25  55   2]
#  [ 19 199  18]
#  [  5  72  24]]
# Scores:
#
# AUC:  0.679	Kappa: 0.205	Accuracy: 0.592
# ------------------------------------------------------
#
# joy
# Confusion Matrix for joy:
#
# [[ 24  46   1]
#  [ 11 148  11]
#  [  2  28  29]]
# Scores:
#
# AUC:  0.764	Kappa: 0.371	Accuracy: 0.67
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 24  54   5]
#  [ 15 120  22]
#  [  3  27  31]]
# Scores:
#
# AUC:  0.713	Kappa: 0.271	Accuracy: 0.581
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 24  41   0]
#  [  8 145   8]
#  [  2  37  36]]
# Scores:
#
# AUC:  0.766	Kappa: 0.413	Accuracy: 0.681
# ------------------------------------------------------
#
# sadness
# Confusion Matrix for sadness:
#
# [[  9  64   1]
#  [  3 139   8]
#  [  2  49  11]]
# Scores:
#
# AUC:  0.684	Kappa: 0.129	Accuracy: 0.556
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 13  55   2]
#  [ 12 133   4]
#  [  2  60   6]]
# Scores:
#
# AUC:  0.651	Kappa: 0.093	Accuracy: 0.53
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[  9  57   0]
#  [  5 148   1]
#  [  1  57   9]]
# Scores:
#
# AUC:  0.687	Kappa: 0.14	Accuracy: 0.578
# ------------------------------------------------------
#
# Experiment 13 Average scores:
#
#  Average AUC: 0.673	 Average Kappa: 0.18	 Average Accuracy: 0.601

# %%
for k in best_classifiers.keys():
    print('///////////{}////////////'.format(k))
    print('///////////{}////////////'.format(best_scores[k]))
    print(best_classifiers[k])
# Out:
# ///////////anger////////////
# ///////////1.6203333333333334////////////
# (Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('tf-idf',
#                                                  TfidfVectorizer(tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2af0>>)),
#                                                 ('doc2vec',
#                                                  Doc2VecTransformer(model=<gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7fdc90143670>,
#                                                                     remove_stopwords=True,
#                                                                     tokenizer=<nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2820>))])),
#                 ('clf',
#                  LogisticRegression(multi_class='ovr', solver='liblinear'))]), 5)
# ///////////fear////////////
# ///////////1.624////////////
# (Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('tf-idf',
#                                                  TfidfVectorizer(tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2af0>>)),
#                                                 ('doc2vec',
#                                                  Doc2VecTransformer(model=<gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7fdc90143670>,
#                                                                     remove_stopwords=True,
#                                                                     tokenizer=<nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2820>))])),
#                 ('clf',
#                  LogisticRegression(multi_class='ovr', solver='liblinear'))]), 5)
# ///////////joy////////////
# ///////////1.779////////////
# (Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('bow',
#                                                  CountVectorizer(ngram_range=(1,
#                                                                               4),
#                                                                  tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2c10>>)),
#                                                 ('chars_count',
#                                                  CharsCountTransformer()),
#                                                 ('doc2vec',
#                                                  Doc2VecTransformer(model=<gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7fdc90143670>,
#                                                                     tokenizer=<nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2700>)),
#                                                 ('liu',
#                                                  LiuFeatureExtractor(tokenizer=<nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2f10>)),
#                                                 ('vader',
#                                                  VaderFeatureExtractor())])),
#                 ('clf',
#                  LogisticRegression(multi_class='ovr', solver='liblinear'))]), 12)
# ///////////sadness////////////
# ///////////1.544////////////
# (Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('tf-idf',
#                                                  TfidfVectorizer(tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2af0>>)),
#                                                 ('doc2vec',
#                                                  Doc2VecTransformer(model=<gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7fdc90143670>,
#                                                                     tokenizer=<nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2700>))])),
#                 ('clf',
#                  LogisticRegression(multi_class='ovr', solver='liblinear'))]), 6)

# %%
# pipeline = get_experiment_0_pipeline()

classifiers = []
learned_labels_array = []
scores_array = []

# Por cada nombre_dataset, dataset en train ('anger', 'fear', 'joy', 'sadness')
for dataset_name, dataset in train.items():
    pipeline, n = best_classifiers[dataset_name]

    # ejecutamos el pipeline sobre el dataset
    classifier, learned_labels, scores = run(dataset, dataset_name, pipeline)

    # guardamos el clasificador entrenado (en realidad es el pipeline ya entrenado...)
    print(classifier)
    classifiers.append(classifier)

    # guardamos las labels aprendidas por el clasificador
    learned_labels_array.append(learned_labels)

    # guardamos los scores obtenidos
    scores_array.append(scores)

# print avg scores
print("Average scores:\n\n",
  "Average AUC: {0:.3g}\t Average Kappa: {1:.3g}\t Average Accuracy: {2:.3g}"
  .format(*np.array(scores_array).mean(axis=0)))
# Out:
# Couldnt find any embedding for tweet:
# I can't even right now #bb18
# I think they may be
# Confusion Matrix for anger:
#
# [[ 23  30   1]
#  [ 23 162  19]
#  [  2  28  25]]
# Scores:
#
# AUC:  0.705	Kappa: 0.329	Accuracy: 0.671
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# I can't even right now #bb18
# I think they may be
# Confusion Matrix for anger:
#
# [[ 19  28   6]
#  [ 33 147  25]
#  [  2  26  28]]
# Scores:
#
# AUC:  0.649	Kappa: 0.264	Accuracy: 0.618
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# I can't even right now #bb18
# I think they may be
# I think they may be
# I think they may be
# Confusion Matrix for anger:
#
# [[ 20  34   0]
#  [ 27 152  29]
#  [  1  30  21]]
# Scores:
#
# AUC:  0.683	Kappa: 0.216	Accuracy: 0.615
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# I can't even right now #bb18
# I think they may be
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('tf-idf',
#                                                  TfidfVectorizer(tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2af0>>)),
#                                                 ('doc2vec',
#                                                  Doc2VecTransformer(model=<gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7fdc90143670>,
#                                                                     remove_stopwords=True,
#                                                                     tokenizer=<nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2820>))])),
#                 ('clf',
#                  LogisticRegression(multi_class='ovr', solver='liblinear'))])
# Couldnt find any embedding for tweet:
# That goes the
# Couldnt find any embedding for tweet:
# And here we go again 😓
# Confusion Matrix for fear:
#
# [[ 43  49   9]
#  [ 40 158  35]
#  [  7  33  45]]
# Scores:
#
# AUC:  0.717	Kappa: 0.296	Accuracy: 0.587
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# And here we go again 😓
# That goes the
# That goes the
# Confusion Matrix for fear:
#
# [[ 38  49   6]
#  [ 34 174  32]
#  [  4  40  42]]
# Scores:
#
# AUC:  0.709	Kappa: 0.298	Accuracy: 0.606
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# And here we go again 😓
# Couldnt find any embedding for tweet:
# That goes the
# Confusion Matrix for fear:
#
# [[ 47  41   6]
#  [ 48 144  34]
#  [  9  47  43]]
# Scores:
#
# AUC:  0.702	Kappa: 0.263	Accuracy: 0.558
# ------------------------------------------------------
#
# Couldnt find any embedding for tweet:
# And here we go again 😓
# That goes the
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('tf-idf',
#                                                  TfidfVectorizer(tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2af0>>)),
#                                                 ('doc2vec',
#                                                  Doc2VecTransformer(model=<gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7fdc90143670>,
#                                                                     remove_stopwords=True,
#                                                                     tokenizer=<nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2820>))])),
#                 ('clf',
#                  LogisticRegression(multi_class='ovr', solver='liblinear'))])
# Confusion Matrix for joy:
#
# [[ 28  47   1]
#  [ 14 128  12]
#  [  0  40  30]]
# Scores:
#
# AUC:  0.769	Kappa: 0.325	Accuracy: 0.62
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 37  37   2]
#  [ 21 129  12]
#  [  1  35  27]]
# Scores:
#
# AUC:  0.759	Kappa: 0.362	Accuracy: 0.641
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 35  31   1]
#  [ 36 116  20]
#  [  6  20  36]]
# Scores:
#
# AUC:  0.75	Kappa: 0.355	Accuracy: 0.621
# ------------------------------------------------------
#
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('bow',
#                                                  CountVectorizer(ngram_range=(1,
#                                                                               4),
#                                                                  tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2c10>>)),
#                                                 ('chars_count',
#                                                  CharsCountTransformer()),
#                                                 ('doc2vec',
#                                                  Doc2VecTransformer(model=<gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7fdc90143670>,
#                                                                     tokenizer=<nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2700>)),
#                                                 ('liu',
#                                                  LiuFeatureExtractor(tokenizer=<nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2f10>)),
#                                                 ('vader',
#                                                  VaderFeatureExtractor())])),
#                 ('clf',
#                  LogisticRegression(multi_class='ovr', solver='liblinear'))])
# Confusion Matrix for sadness:
#
# [[ 30  33   6]
#  [ 15 121  17]
#  [  4  33  27]]
# Scores:
#
# AUC:  0.706	Kappa: 0.337	Accuracy: 0.622
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 26  46   1]
#  [ 19 109  22]
#  [  5  30  29]]
# Scores:
#
# AUC:  0.676	Kappa: 0.259	Accuracy: 0.571
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 28  37   3]
#  [ 25 110  15]
#  [  6  33  30]]
# Scores:
#
# AUC:  0.724	Kappa: 0.289	Accuracy: 0.585
# ------------------------------------------------------
#
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('tf-idf',
#                                                  TfidfVectorizer(tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2af0>>)),
#                                                 ('doc2vec',
#                                                  Doc2VecTransformer(model=<gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7fdc90143670>,
#                                                                     tokenizer=<nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2700>))])),
#                 ('clf',
#                  LogisticRegression(multi_class='ovr', solver='liblinear'))])
# Average scores:
#
#  Average AUC: 0.712	 Average Kappa: 0.299	 Average Accuracy: 0.61

# %%
pipeline = get_experiment_0_pipeline()

classifiers = []
learned_labels_array = []
scores_array = []

# Por cada nombre_dataset, dataset en train ('anger', 'fear', 'joy', 'sadness')
for dataset_name, dataset in train.items():
#     pipeline, n = best_classifiers[dataset_name]

    # ejecutamos el pipeline sobre el dataset
    classifier, learned_labels, scores = run(dataset, dataset_name, pipeline)

    # guardamos el clasificador entrenado (en realidad es el pipeline ya entrenado...)
    print(classifier)
    classifiers.append(classifier)

    # guardamos las labels aprendidas por el clasificador
    learned_labels_array.append(learned_labels)

    # guardamos los scores obtenidos
    scores_array.append(scores)

# print avg scores
print("Average scores:\n\n",
  "Average AUC: {0:.3g}\t Average Kappa: {1:.3g}\t Average Accuracy: {2:.3g}"
  .format(*np.array(scores_array).mean(axis=0)))
# Out:
# Confusion Matrix for anger:
#
# [[ 10  37   2]
#  [ 12 176  24]
#  [  0  35  17]]
# Scores:
#
# AUC:  0.613	Kappa: 0.182	Accuracy: 0.649
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[ 14  37   2]
#  [ 20 163  29]
#  [  1  29  19]]
# Scores:
#
# AUC:  0.601	Kappa: 0.19	Accuracy: 0.624
# ------------------------------------------------------
#
# Confusion Matrix for anger:
#
# [[  9  50   0]
#  [ 13 161  19]
#  [  3  43  16]]
# Scores:
#
# AUC:  0.575	Kappa: 0.125	Accuracy: 0.592
# ------------------------------------------------------
#
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('bow',
#                                                  CountVectorizer(ngram_range=(1,
#                                                                               4),
#                                                                  tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2c10>>))])),
#                 ('clf', MultinomialNB())])
# Confusion Matrix for fear:
#
# [[ 33  50   6]
#  [ 15 192  27]
#  [  2  59  35]]
# Scores:
#
# AUC:  0.627	Kappa: 0.292	Accuracy: 0.621
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 42  45  10]
#  [ 28 167  35]
#  [  5  53  34]]
# Scores:
#
# AUC:  0.653	Kappa: 0.263	Accuracy: 0.58
# ------------------------------------------------------
#
# Confusion Matrix for fear:
#
# [[ 38  56   8]
#  [ 30 162  43]
#  [  6  35  41]]
# Scores:
#
# AUC:  0.663	Kappa: 0.262	Accuracy: 0.575
# ------------------------------------------------------
#
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('bow',
#                                                  CountVectorizer(ngram_range=(1,
#                                                                               4),
#                                                                  tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2c10>>))])),
#                 ('clf', MultinomialNB())])
# Confusion Matrix for joy:
#
# [[ 21  40   3]
#  [ 27 118  19]
#  [  1  28  43]]
# Scores:
#
# AUC:  0.716	Kappa: 0.315	Accuracy: 0.607
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 20  54   1]
#  [ 22 126  13]
#  [  4  30  31]]
# Scores:
#
# AUC:  0.705	Kappa: 0.26	Accuracy: 0.588
# ------------------------------------------------------
#
# Confusion Matrix for joy:
#
# [[ 31  44   5]
#  [ 37 100  26]
#  [  1  14  43]]
# Scores:
#
# AUC:  0.693	Kappa: 0.305	Accuracy: 0.578
# ------------------------------------------------------
#
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('bow',
#                                                  CountVectorizer(ngram_range=(1,
#                                                                               4),
#                                                                  tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2c10>>))])),
#                 ('clf', MultinomialNB())])
# Confusion Matrix for sadness:
#
# [[ 15  57   1]
#  [ 13 121  14]
#  [  3  48  14]]
# Scores:
#
# AUC:  0.617	Kappa: 0.12	Accuracy: 0.524
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 20  44   3]
#  [ 23 120   8]
#  [  3  42  24]]
# Scores:
#
# AUC:  0.665	Kappa: 0.229	Accuracy: 0.571
# ------------------------------------------------------
#
# Confusion Matrix for sadness:
#
# [[ 11  59   0]
#  [ 14 130  10]
#  [  3  35  25]]
# Scores:
#
# AUC:  0.685	Kappa: 0.205	Accuracy: 0.578
# ------------------------------------------------------
#
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('bow',
#                                                  CountVectorizer(ngram_range=(1,
#                                                                               4),
#                                                                  tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2c10>>))])),
#                 ('clf', MultinomialNB())])
# Average scores:
#
#  Average AUC: 0.651	 Average Kappa: 0.229	 Average Accuracy: 0.591

# %% [markdown]
# ### Predecir los target set y crear la submission
#
# Aquí predecimos los target set usando los clasificadores creados y creamos los archivos de las submissions.

# %%
def predict_target(dataset, classifier, labels):
    # Predecir las probabilidades de intensidad de cada elemento del target set.
    predicted = pd.DataFrame(classifier.predict_proba(dataset.tweet), columns=labels)
    # Agregar ids
    predicted['id'] = dataset.id.values
    # Reordenar las columnas
    predicted = predicted[['id', 'low', 'medium', 'high']]
    return predicted

# %%
predicted_target = {}

# Crear carpeta ./predictions
if (not os.path.exists('./predictions')):
    os.mkdir('./predictions')

else:
    # Eliminar predicciones anteriores:
    shutil.rmtree('./predictions')
    os.mkdir('./predictions')

# por cada target set:
for idx, key in enumerate(target):
    # Predecirlo
    print(key)
#     classifier, n = best_classifiers[key]
    classifier = classifiers[idx]
    print(classifier)
    predicted_target[key] = predict_target(target[key], classifier,
                                           learned_labels_array[idx])
    # Guardar predicciones en archivos separados. 
    predicted_target[key].to_csv('./predictions/{}-pred.txt'.format(key),
                                 sep='\t',
                                 header=False,
                                 index=False)

# Crear archivo zip
a = shutil.make_archive('predictions', 'zip', './predictions')
# Out:
# anger
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('bow',
#                                                  CountVectorizer(ngram_range=(1,
#                                                                               4),
#                                                                  tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2c10>>))])),
#                 ('clf', MultinomialNB())])
# fear
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('bow',
#                                                  CountVectorizer(ngram_range=(1,
#                                                                               4),
#                                                                  tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2c10>>))])),
#                 ('clf', MultinomialNB())])
# joy
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('bow',
#                                                  CountVectorizer(ngram_range=(1,
#                                                                               4),
#                                                                  tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2c10>>))])),
#                 ('clf', MultinomialNB())])
# sadness
# Pipeline(steps=[('features',
#                  FeatureUnion(transformer_list=[('bow',
#                                                  CountVectorizer(ngram_range=(1,
#                                                                               4),
#                                                                  tokenizer=<bound method TweetTokenizer.tokenize of <nltk.tokenize.casual.TweetTokenizer object at 0x7fdc285b2c10>>))])),
#                 ('clf', MultinomialNB())])

# %% [markdown]
# ## 6. Conclusiones

# %% [markdown]
# Los experimentos implementados consisten en una exploración de las distintas formas de representar un texto, con el enfoque en el análisis de la intensidad del sentimiento (que no es lo mismo que el análisis de sentimiento como tal). Esto le agrega una mayor complejidad al problema, ya que a veces incluso para un humano es difícil decidir si la intensidad es media o baja, por ejemplo.
#
# A partir de los resultados obtenidos, se obtiene que los clasificadores entregan un desempeño similar. Además, se infiere que sin eliminar los stopwords arroja un mejor resultado que eliminándolos, lo cual tiene sentido, ya que la intensidad del sentimiento muchas veces está representada por los conectores y los adverbios (por ejemplo en las exageraciones). También, se concluye que tanto el stemming como la lematización no producen grandes cambios en los resultados, pues la conjugación de las palabras no guardan tanta relación con la intensidad de sentimiento como tal.
#
# A medida que se van agregando más representaciones, en general el resultado mejora, salvo en algunos casos donde se considera que se están agregando información repetida (por ejemplo el sentiment score de Vader y TextBlob).
#
# El accuracy más alto alcanzado es 62%, que dista aún bastante de ser un resultado óptimo. Como trabajo futuro, se propone profundizar más en la representación por word embeddings, ya que en este trabajo se consideró el promedio por índice de los vectores de cada palabra, lo cual puede estar causando una pérdida de información. También, se puede realizar una exploración más exhaustiva de los datos para determinar manualmente otros features relevantes.
